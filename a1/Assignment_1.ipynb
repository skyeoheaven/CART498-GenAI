# %%
import datetime, pytz

current_time = datetime.datetime.now(pytz.timezone('US/Eastern')).strftime("%H:%M")
print(f"This is Skye O'Hearn-Smith's first assigment for CART498. The current time is {current_time}")
# Out:
# This is Skye O'Hearn-Smith's first assigment for CART498. The current time is 13:21

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    # "Lykon/dreamshaper-8",
    "stabilityai/sd-turbo",
    # "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16,
    ).to(device)
# Out:
# model_index.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/574 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# scheduler_config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# text_encoder/model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# ...

# %%
prompt = "dogs playing poker. in the style of a dadist collage. tableau. realistic collage, flat 2d style. cutout collage style "
pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "cats playing mahjong. in the style of a dadist collage. tableau. realistic collage, flat 2d style. cutout collage style "
pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = "rabbits playing slots. in the style of a dadist collage. tableau. realistic collage, flat 2d style. cutout collage style "
pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
